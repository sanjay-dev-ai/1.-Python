# %% [markdown]
# #1.Identify and fix the syntax error in the following code:
#
#
# age = 18
# if age >= 18
#     print("You are eligible to vote")

# %%
#Answer: Added paranthesis and (:) to fix the code.

age = 18
if (age >= 18):
    print ("You are eligible to vote")

# %% [markdown]
# #2.Question:
# What error will occur in the following code?
#
#
# def greet():
#     print("Hello, World!")
#
# greet_user()

# %%
#Answer: Fixing the function call

def greet():
    print("Hello, World!")

greet()

# %% [markdown]
# #3.Identify the error in this code:
#
# name = "Alice"
# age = 25
# print("My name is " + name + " and I am " + age + " years old.")

# %%
#Answer: chnaged the age to string to concatenate

name = "Alice"
age = "25"
print("My name is " + name + " and I am " + age + " years old.")

# %% [markdown]
# #4.Question:
# What will happen when you run this code?
#
# a = 10
# b = 0
# result = a / b
# print(result)

# %%
#Answer:

a = 10
b = 0
if (b == 0):
    print("None of the number can't divided by Zero")
else:
    result = a / b
    print(result)

# %% [markdown]
# #5.What error will occur in the following code?
#
# num = int("xyz")
# print(num)

# %%
#Answer: Got the value error, Since for the interger can't pass the string. So, Added the condition to check the given input is a integer.

try:
    num = int("xyz")
except ValueError:
    print("Inavlid Input")

# %% [markdown]
# #6.Identify the issue in this code:
#
# data = {"name": "John", "age": 30}
# print(data["city"])

# %%
#Answer: The is no data in the dictinary with the key "city". So, Exceting the get method to fix the KeyError. 

data = {"name": "John", "age": 30}
print(data.get("city","Not Found"))

# %% [markdown]
# #7.What will happen when you run this code?
# num = 1
# while num < 5:
#     print(num)

# %%
#Answer: Breaking the loop to get the output.

num = 1

while num < 5:
    print(num)
    num += 1

# %% [markdown]
# #8.What is wrong with this code?
#
# fruits = ("apple", "banana", "cherry")
# print(fruits[3])

# %%
#Answer: Index error due to out of the range. Since changed the index within the range to get the output. 

fruits = ("apple", "banana", "cherry")
print(fruits[2])

# %% [markdown]
# #9.What will happen when you run this code?
#
# text = "hello world"
# text.append("!")

# %%
#Answer: Append can be used for only lists. So, Chaging the code as per the string. 

text = "hello world"
text = text + "!"
print (text)

# %% [markdown]
# #10.What is wrong with the following code?
#
# import randoms
# print(randoms.randint(1, 10))

# %%
#Answer: There is no module as "randoms". Fix it with exact module as "random".Additionally, 'randint' will generates the randiom number in given range. 

import random
print(random.randint(1, 10))
